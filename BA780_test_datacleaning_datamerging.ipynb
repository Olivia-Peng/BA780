# %% [markdown]
# <a href="https://colab.research.google.com/github/Olivia-Peng/BA780_test/blob/main/BA780_test_datacleaning_datamerging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
kaggle = pd.read_excel("/content/Spotify and Youtube (test).xlsx")
#print(kaggle)

# %%
import pandas as pd
wAPI = pd.read_excel("/content/Spotify_Youtube_wAPI (test).xlsx")
#print(wAPI)

# %%
# Q1, what is the difference between ["Unnamed: 0.1"] & ["Unnamed: 0"] ✅
  # figure out that there might be some duplicated value -> check

# shows that there really exist duplicated value
wAPI[wAPI.duplicated(subset=["Artist","Url_spotify","Track"])]

# drop the duplicated value
wAPI.drop_duplicates(subset=["Artist","Url_spotify","Track"],inplace = True)

# new wAPI without duplicated value
wAPI
# Out:
#        Unnamed: 0.1  Unnamed: 0       Artist  \
# 0                 0           0     Gorillaz
# 1                 1           1     Gorillaz
# 2                 2           2     Gorillaz
# 5                 5           3     Gorillaz
# 6                 6           4     Gorillaz
# ...             ...         ...          ...
# 25285         25285       20713  SICK LEGEND
# 25286         25286       20714  SICK LEGEND
# 25287         25287       20715  SICK LEGEND
# 25288         25288       20716  SICK LEGEND
# 25289         25289       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# ...

# %%
# Q2, if I want to join wAPI and kaggle data together, need to ensure that all the songs are in sync with each other ✅

# set kaggle as true_data & set wAPI as study_data, find out if there any info in study_data that is out of the true_data range
difference = set(wAPI["Track"]).difference(kaggle["Track"])
print(difference)
# Out:
# set()

# %%
# Q3, drop of the ["Unnamed: 0.1"] from wAPI, it's a redundant information ✅

wAPI.drop("Unnamed: 0.1",axis=1,inplace=True)
                      # make sure to set axis=1 (whole column)

# %%
# just to make sure the 2 datasets are now joinable ✅
wAPI.to_excel('wAPI.xlsx')

# %%
# Q4, different columns between wAPI and kaggle ✅
different_columns = set(wAPI.columns).difference(kaggle.columns)
print(different_columns)
# Out:
# {'Genres', 'Artist Popularity', 'Track Popularity'}

# %%
# Q5, add new three columns:{'Genres', 'Artist Popularity', 'Track Popularity'} to kaggle using outer join, create a whole new dataset = dataset ✅

""" OUTER JOIN (return all of the rows and columns from both tables, doesn't matter if there is a match between the table)
f1.merge(f2,how="outer",suffixes=("_f1","_f2"),on="")
"""

common_columns = ['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
       'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
       'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
       'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
       'Comments', 'Description', 'Licensed', 'official_video', 'Stream']

dataset = kaggle.merge(wAPI, on=common_columns  ,how="outer")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20718 entries, 0 to 20717
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Artist             20718 non-null  object
#  1   Url_spotify        20718 non-null  object
#  2   Track              20716 non-null  object
#  3   Album              20708 non-null  object
#  4   Album_type         20718 non-null  object
#  5   Uri                20718 non-null  object
#  6   Danceability       20716 non-null  float64
#  7   Energy             20716 non-null  float64
#  8   Key                20716 non-null  float64
#  9   Loudness           20716 non-null  float64
#  10  Speechiness        20716 non-null  float64
#  11  Acousticness       20716 non-null  float64
#  12  Instrumentalness   20716 non-null  float64
#  13  Liveness           20716 non-null  float64
#  14  Valence            20716 non-null  float64
# ...

# %%
dataset
# Out:
#             Artist                                        Url_spotify  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %%
dataset.to_excel('dataset.xlsx')
